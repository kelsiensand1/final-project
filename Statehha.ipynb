# %%
import pandas as pd
import numpy as np
#imported pandas and renamed as pd

# %%
bls = pd.read_csv('/Users/kelsiesandoval/Desktop/Projects/Data-journalism/final-project/data/state_M2018_dl.csv')
bls
#imported csv from Bureau of labor statistics
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# ...     ...  ..             ...      ...
# 36892    78  VI  Virgin Islands  53-6031
# 36893    78  VI  Virgin Islands  53-6099
# 36894    78  VI  Virgin Islands  53-7051
# 36895    78  VI  Virgin Islands  53-7062
# 36896    78  VI  Virgin Islands  53-7064
#
#                                                OCC_TITLE OCC_GROUP    TOT_EMP  \
# 0                                        All Occupations     total  1,943,760
# 1                                 Management Occupations     major     73,860
# 2                                       Chief Executives  detailed      1,390
# 3                        General and Operations Managers  detailed     28,600
# ...

# %%
bls.shape
# Out:
# (36897, 25)

# %%
bls.dtypes
# Out:
# AREA          int64
# ST           object
# STATE        object
# OCC_CODE     object
# OCC_TITLE    object
# OCC_GROUP    object
# TOT_EMP      object
# EMP_PRSE     object
# JOBS_1000    object
# LOC_Q        object
# H_MEAN       object
# A_MEAN       object
# MEAN_PRSE    object
# H_PCT10      object
# H_PCT25      object
# H_MEDIAN     object
# H_PCT75      object
# H_PCT90      object
# A_PCT10      object
# A_PCT25      object
# A_MEDIAN     object
# A_PCT75      object
# A_PCT90      object
# ANNUAL       object
# HOURLY       object
# dtype: object

# %%
NY_state = bls[bls['STATE'] == 'New York']
NY_state
#saved new dataframe with only New York State
# Out:
#        AREA  ST     STATE OCC_CODE  \
# 22466    36  NY  New York  00-0000
# 22467    36  NY  New York  11-0000
# 22468    36  NY  New York  11-1011
# 22469    36  NY  New York  11-1021
# 22470    36  NY  New York  11-1031
# ...     ...  ..       ...      ...
# 23257    36  NY  New York  53-7063
# 23258    36  NY  New York  53-7064
# 23259    36  NY  New York  53-7071
# 23260    36  NY  New York  53-7081
# 23261    36  NY  New York  53-7199
#
#                                               OCC_TITLE OCC_GROUP    TOT_EMP  \
# 22466                                   All Occupations     total  9,385,620
# 22467                            Management Occupations     major    482,770
# 22468                                  Chief Executives  detailed     10,430
# 22469                   General and Operations Managers  detailed    163,250
# 22470                                       Legislators  detailed      6,220
# ...

# %%
NY_state_hha = NY_state[NY_state['OCC_CODE']== '31-1011']
NY_state_hha
#Filtered to view only home health aides
# Out:
#        AREA  ST     STATE OCC_CODE          OCC_TITLE OCC_GROUP  TOT_EMP  \
# 22820    36  NY  New York  31-1011  Home Health Aides  detailed  191,820
#
#       EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10 A_PCT25  \
# 22820      3.5    20.437  3.71  ...    11.98   13.62   15.07  22,290  23,290
#
#       A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 22820   24,920  28,330  31,340    NaN    NaN
#
# [1 rows x 25 columns]

# %%
filtered= NY_state[(NY_state["TOT_EMP"]!="**")& (NY_state["A_MEDIAN"]!="**")& (NY_state["A_MEDIAN"]!="#")&(NY_state["A_MEDIAN"]!="*")]

# %%
filtered["TOT_EMP"]=filtered["TOT_EMP"].str.replace(",", "").astype(int)
# Out:
# <ipython-input-172-6606c3a13ddd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered["TOT_EMP"]=filtered["TOT_EMP"].str.replace(",", "").astype(int)

# %%
filtered["A_MEDIAN"]=filtered["A_MEDIAN"].str.replace(",", "").astype(int)
# Out:
# <ipython-input-173-98cf25188c80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered["A_MEDIAN"]=filtered["A_MEDIAN"].str.replace(",", "").astype(int)

# %%
contact = pd.read_csv('/Users/kelsiesandoval/Desktop/Projects/Data-journalism/final-project/data/Contact_With_Others.csv')
contact
#imported data from O-NET about human contact levels by occupation
# Out:
#      Context        Code                                         Occupation
# 0        100  29-1069.01                       Allergists and Immunologists
# 1        100  29-1011.00                                      Chiropractors
# 2        100  29-2021.00                                  Dental Hygienists
# 3        100  29-1069.02                                     Dermatologists
# 4        100  11-9031.00  Education Administrators, Preschool and Childc...
# ..       ...         ...                                                ...
# 963       46  51-3022.00       Meat, Poultry, and Fish Cutters and Trimmers
# 964       46  51-9122.00                 Painters, Transportation Equipment
# 965       44  27-3043.05              Poets, Lyricists and Creative Writers
# 966       40  45-2092.02                     Farmworkers and Laborers, Crop
# 967       25  15-2091.00                           Mathematical Technicians
#
# [968 rows x 3 columns]

# %%
contact['Code'] = contact['Code'].str[:7]
contact
#trimmed occupation code to match NYS BLS dataset
# Out:
#      Context     Code                                         Occupation
# 0        100  29-1069                       Allergists and Immunologists
# 1        100  29-1011                                      Chiropractors
# 2        100  29-2021                                  Dental Hygienists
# 3        100  29-1069                                     Dermatologists
# 4        100  11-9031  Education Administrators, Preschool and Childc...
# ..       ...      ...                                                ...
# 963       46  51-3022       Meat, Poultry, and Fish Cutters and Trimmers
# 964       46  51-9122                 Painters, Transportation Equipment
# 965       44  27-3043              Poets, Lyricists and Creative Writers
# 966       40  45-2092                     Farmworkers and Laborers, Crop
# 967       25  15-2091                           Mathematical Technicians
#
# [968 rows x 3 columns]

# %%
contact_occ_code = contact.rename(columns={'Code':'OCC_CODE'})
contact_occ_code
#renamed O-NET column header to match NYS BLS dataset to ease merge
# Out:
#      Context OCC_CODE                                         Occupation
# 0        100  29-1069                       Allergists and Immunologists
# 1        100  29-1011                                      Chiropractors
# 2        100  29-2021                                  Dental Hygienists
# 3        100  29-1069                                     Dermatologists
# 4        100  11-9031  Education Administrators, Preschool and Childc...
# ..       ...      ...                                                ...
# 963       46  51-3022       Meat, Poultry, and Fish Cutters and Trimmers
# 964       46  51-9122                 Painters, Transportation Equipment
# 965       44  27-3043              Poets, Lyricists and Creative Writers
# 966       40  45-2092                     Farmworkers and Laborers, Crop
# 967       25  15-2091                           Mathematical Technicians
#
# [968 rows x 3 columns]

# %%
merged_data.dtypes
# Out:
# OCC_CODE     object
# TOT_EMP       int64
# A_MEDIAN      int64
# OCC_TITLE    object
# dtype: object

# %%
merged_data = pd.merge(filtered, contact_occ_code, on='OCC_CODE')
merged_data
#merged O-NET and BLS by occupation code ('OCC_CODE')
# Out:
#      AREA  ST     STATE OCC_CODE  \
# 0      36  NY  New York  11-1021
# 1      36  NY  New York  11-2011
# 2      36  NY  New York  11-2021
# 3      36  NY  New York  11-2022
# 4      36  NY  New York  11-2031
# ..    ...  ..       ...      ...
# 853    36  NY  New York  53-7062
# 854    36  NY  New York  53-7063
# 855    36  NY  New York  53-7064
# 856    36  NY  New York  53-7071
# 857    36  NY  New York  53-7081
#
#                                              OCC_TITLE OCC_GROUP  TOT_EMP  \
# 0                      General and Operations Managers  detailed   163250
# 1                  Advertising and Promotions Managers  detailed     6590
# 2                                   Marketing Managers  detailed    17590
# 3                                       Sales Managers  detailed    23120
# 4            Public Relations and Fundraising Managers  detailed     6190
# ..                                                 ...       ...      ...
# ...

# %%
merged_data = merged_data[['OCC_CODE', 'TOT_EMP', 'A_MEDIAN', 'OCC_TITLE','Context']]
merged_data
#saved new dataframe with only occupation code, total employees, and average income
# Out:
#     OCC_CODE  TOT_EMP  A_MEDIAN  \
# 0    11-1021   163250    129690
# 1    11-2011     6590    157710
# 2    11-2021    17590    172230
# 3    11-2022    23120    180360
# 4    11-2031     6190    149400
# ..       ...      ...       ...
# 853  53-7062   130850     29360
# 854  53-7063     1370     28620
# 855  53-7064    23220     25930
# 856  53-7071       70     59520
# 857  53-7081    10480     59440
#
#                                              OCC_TITLE  Context
# 0                      General and Operations Managers       95
# 1                  Advertising and Promotions Managers       92
# 2                                   Marketing Managers       90
# 3                                       Sales Managers       96
# 4            Public Relations and Fundraising Managers       97
# ..                                                 ...      ...
# 853  Laborers and Freight, Stock, and Material Move...       75
# ...

# %%
merged_data.dtypes
# Out:
# OCC_CODE     object
# TOT_EMP       int64
# A_MEDIAN      int64
# OCC_TITLE    object
# Context       int64
# dtype: object

# %%
merged_data.to_csv('NYS_contact_hha.csv',index=False)
#saved data as CSV to use for visualization and further analysis
